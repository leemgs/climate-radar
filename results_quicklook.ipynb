# %% [markdown]
# # Climate RADAR Quick Look
#
# Load metrics and preview.

# %%
import json, pathlib
p=pathlib.Path('results/metrics.json')
print(p.read_text()) if p.exists() else print('Run make reproduce first.')
